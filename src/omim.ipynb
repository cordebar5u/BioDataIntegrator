# %%
import pandas as pd
import numpy as np
import seaborn as sns

# Ouvre le fichier
df = pd.read_csv('../data/OMIM/omim_onto.csv')

df.head()
# Out:
#                                             Class ID  \
# 0   http://purl.bioontology.org/ontology/OMIM/600374
# 1  http://purl.bioontology.org/ontology/OMIM/MTHU...
# 2  http://purl.bioontology.org/ontology/OMIM/MTHU...
# 3   http://purl.bioontology.org/ontology/OMIM/606301
# 4   http://purl.bioontology.org/ontology/OMIM/614769
#
#                                      Preferred Label  \
# 0                                          BBS4 GENE
# 1                                   Hypoplastic ilia
# 2                   Reduced number of memory B cells
# 3         PROTOCADHERIN-GAMMA, SUBFAMILY B, MEMBER 3
# 4  CYTOCHROME C OXIDASE ASSEMBLY FACTOR 1, S. CER...
#
#                                             Synonyms  Definitions  Obsolete  \
# 0                                               BBS4          NaN     False
# 1                                                NaN          NaN     False
# 2                                                NaN          NaN     False
# ...
